# %% [markdown]
# 本 notebook 对比当各个detector选取自己最大的disagreement点做阈值的时候，是否能够起到如下两个作用：
# 1. 提高f1
# 2. 甄别 detector

# %%
from __future__ import division,print_function
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np
import os
import sys
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
import re
from sklearn.preprocessing import RobustScaler
import scipy.stats as ss
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
import scipy.io
import os
import sys
from time import time
import scipy.stats as ss
from sklearn.preprocessing import RobustScaler
from sklearn import metrics

# temporary solution for relative imports in case pyod is not installed
# if pyod is installed, no need to use the following line
sys.path.append(
    os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))
from numpy import percentile
import matplotlib.pyplot as plt
import matplotlib.font_manager
# Import all models
from pyod.models.abod import ABOD
from pyod.models.cblof import CBLOF
from pyod.models.feature_bagging import FeatureBagging
from pyod.models.hbos import HBOS
from pyod.models.iforest import IForest
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.pca import PCA
from pyod.models.lscp import LSCP # ensemble
import multiprocessing as mp
from IPython.display import display
from sklearn.metrics import roc_auc_score
from thresholders import *


data_path = "/Users/kadima/experiment_any/anomaly-detection/datasets/"
def getData(fileName):
    # check fileName:
    files = [x for x in os.listdir(data_path) if x.endswith(".mat")]
    mat = scipy.io.loadmat(data_path+fileName)
    X = mat["X"]
    y = mat["y"]
    return X, y

def get_score_matrix(X, num_detectors):
    return np.zeros([X.shape[0], num_detectors])

def get_perform_matrix(num_thresholders, num_detectors):
    return np.zeros((num_thresholders, num_detectors))


random_state = np.random.RandomState(10)
outliers_fraction = 0.4
# initialize a set of detectors for LSCP
detector_list = [LOF(n_neighbors=5), LOF(n_neighbors=10), LOF(n_neighbors=15),
                 LOF(n_neighbors=20), LOF(n_neighbors=25), LOF(n_neighbors=30),
                 LOF(n_neighbors=35), LOF(n_neighbors=40), LOF(n_neighbors=45),
                 LOF(n_neighbors=50)]
classifiers = {
    'Angle-based Outlier Detector (ABOD)':
        ABOD(contamination=outliers_fraction),
#     'Cluster-based Local Outlier Factor (CBLOF)':
#         CBLOF(contamination=outliers_fraction,
#               check_estimator=False, random_state=random_state),
    'Feature Bagging':
        FeatureBagging(LOF(n_neighbors=35),
                       contamination=outliers_fraction,
                       random_state=random_state),
    'Histogram-base Outlier Detection (HBOS)': HBOS(
        contamination=outliers_fraction),
    'Isolation Forest': IForest(contamination=outliers_fraction,
                                random_state=random_state, n_estimators = 280),
    'K Nearest Neighbors (KNN)': KNN(
        contamination=outliers_fraction),
    'Average KNN': KNN(method='mean',
                       contamination=outliers_fraction),
    'Local Outlier Factor (LOF)':
        LOF(n_neighbors=35, contamination=outliers_fraction),
#     'Minimum Covariance Determinant (MCD)': MCD(
#         contamination=outliers_fraction, random_state=random_state),
    'One-class SVM (OCSVM)': OCSVM(contamination=outliers_fraction)
#     'Principal Component Analysis (PCA)': PCA(
#         contamination=outliers_fraction, random_state=random_state),
#     'Locally Selective Combination (LSCP)': LSCP(
#         detector_list, contamination=outliers_fraction,
#         random_state=random_state)
}

names = []
# Show all detectors
for i, clf in enumerate(classifiers.keys()):
    names.append(clf)
#     print('Model', i + 1, clf)

# Fit the models with the generated data and 
# compare model performances
def get_result(X, y, classifiers):
    threshold_records = list()
    # create matrix to store the performance
    score_matrix = get_score_matrix(X, len(classifiers.keys()))
    perform_table = get_perform_matrix(6, len(classifiers.keys()) )

    np.random.seed(5)
    clfs = []

    # Fit the model
    for i, (clf_name, clf) in enumerate(classifiers.items()):
#         print(i + 1, 'fitting', clf_name)
        # fit the data and tag outliers
        clf.fit(X)
        clfs.append(clf)
        scores_pred = clf.decision_function(X)
        score_matrix[:, i] = scores_pred
        

    for i, thresholder in enumerate([sd_thresholder, mad_thresholder, 
                                     iqr_thresholder]):
        kk = []
        for j in range(score_matrix.shape[1]):
            _,perform_table[i,j],b = thresholder(score_matrix[:,j], y)
            kk.append(b)
            
        threshold_records.append(kk)
            
    for i in range(score_matrix.shape[1]):
        perform_table[-3, i] = f1_score(y, clfs[i].predict(X))
        perform_table[-2, i] = roc_auc_score(y, clf.predict_proba(X)[:, 1])

        
    perform_table[-1,:], d_threshold, disagreement_record = disagreement_one_scalar(score_matrix, len(classifiers), y, False)
    threshold_records.append(d_threshold)
    
    return (pd.DataFrame(perform_table, columns = names, 
            index = ["sd",'mad','iqr','default-f1','auc','disagreement']), 
            threshold_records, disagreement_record, score_matrix)

def run_helper(datasets):
    X,y = getData(datasets)
    X = X.astype(np.float64)
    return get_result(X, y, classifiers)


result_dict = dict()
bug_datasets = ["letter.mat","speech.mat","cardio.mat","http.mat", "smtp.mat",
               "ecoli.mat","shuttle.mat","seismic-bumps.arff","mammography.mat","cover.mat"]
for datasets in os.listdir("/Users/kadima/experiment_any/anomaly-detection/datasets/"):
    if datasets in bug_datasets:
        continue
    print(datasets)
    result_dict[datasets] = run_helper(datasets)


display(result_dict["lympho.mat"][0])
# Out:
# pima.mat
# wine.mat
# mnist.mat
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/covariance/_robust_covariance.py:647: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# arrhythmia.mat
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/covariance/_robust_covariance.py:647: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# pendigits.mat
# musk.mat
# thyroid.mat
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# vowels.mat
# optdigits.mat
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/covariance/_robust_covariance.py:647: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# breastw.mat
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# satellite.mat
# lympho.mat
# annthyroid.mat
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:221: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ionosphere.mat
# wbc.mat
# glass.mat
# satimage-2.mat
# vertebral.mat
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/covariance/_robust_covariance.py:166: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (10.756303907296980 > -6.541214171251153). You may want to try with a higher value of support_fraction (current value: 0.517).
#   warnings.warn("Determinant has increased; this should not happen: "
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.666667
# mad                                      0.000000         0.077922
# iqr                                      0.000000         0.714286
# default-f1                               0.166667         0.187500
# auc                                      0.977700         0.977700
# disagreement                             0.296296         0.285714
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.800000          0.909091
# mad                                          0.000000          0.909091
# iqr                                          0.857143          0.769231
# default-f1                                   0.184615          0.184615
# auc                                          0.977700          0.977700
# disagreement                                 0.800000          0.909091
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.600000     0.600000
# mad                            0.077922     0.077922
# iqr                            0.500000     0.533333
# default-f1                     0.342857     0.500000
# auc                            0.977700     0.977700
# disagreement                   0.476190     0.555556
#
#               Local Outlier Factor (LOF)  \
# sd                              0.666667
# mad                             0.077922
# iqr                             0.666667
# default-f1                      0.184615
# auc                             0.977700
# disagreement                    0.285714
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.500000               0.400000
# mad                                       0.218182               0.545455
# iqr                                       0.500000               0.545455
# default-f1                                0.184615               0.184615
# auc                                       0.977700               0.977700
# disagreement                              0.235294               0.444444

# %%
for datasets in os.listdir("/Users/kadima/experiment_any/anomaly-detection/datasets/"):
    if datasets in bug_datasets:
        continue
    else:
        print(datasets)
        print(np.sum(result_dict[datasets][2],axis=0))
        idx_worst = np.argmax(np.median(result_dict[datasets][2],axis=0))
        idx_best = np.argmin(np.median(result_dict[datasets][2],axis=0))

#         print(names[idx_worst],'is worst')
#         print(names[idx_best], 'is best')
        display(result_dict[datasets][0])
        display(pd.DataFrame(np.asarray(result_dict[datasets][1]).reshape(-1,9),
                             columns=result_dict[datasets][0].columns, 
                             index = ['sd', 'mad', 'iqr','disagreement']))
        print("=="*55)
        print("\n\n")
# Out:
# pima.mat
# 525.4917015719627
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.063380
# mad                                      0.000000         0.517375
# iqr                                      0.000000         0.158824
# default-f1                               0.481802         0.422383
# auc                                      0.539302         0.539302
# disagreement                             0.014815         0.014815
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.095563          0.070671
# mad                                          0.517375          0.057143
# iqr                                          0.126667          0.057143
# default-f1                                   0.528696          0.566957
# auc                                          0.539302          0.539302
# disagreement                                 0.532020          0.022059
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.036101     0.043321
# mad                            0.465649     0.472441
# iqr                            0.155340     0.118421
# default-f1                     0.475836     0.379391
# auc                            0.539302     0.539302
# disagreement                   0.007435     0.007435
#
#               Local Outlier Factor (LOF)  \
# sd                              0.056140
# mad                             0.517375
# iqr                             0.171254
# default-f1                      0.441652
# auc                             0.539302
# disagreement                    0.007435
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.115254               0.000000
# mad                                       0.364066               0.000000
# iqr                                       0.234957               0.000000
# default-f1                                0.553043               0.420870
# auc                                       0.539302               0.539302
# disagreement                              0.007435               0.500566
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                   3.898839e-05         1.609722
# mad                                  8.458347e-06         0.212685
# iqr                                  1.200092e-05         1.276634
# disagreement                        -1.441992e-10         2.914823
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                          23.108828          0.118350
# mad                                          2.817009          0.125791
# iqr                                         22.778228          0.124183
# disagreement                                20.243166          0.159419
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                            57.780390    38.123400
# mad                           21.504689    15.494152
# iqr                           38.740957    28.037795
# disagreement                 270.980410   161.994200
#
#               Local Outlier Factor (LOF)  \
# sd                              1.612252
# mad                             0.240251
# iqr                             1.293413
# disagreement                    3.231154
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                       59.229399               0.000733
# mad                                      19.780183               0.001121
# iqr                                      32.865689               0.001047
# disagreement                            153.184688              -0.000239
# ==============================================================================================================
#
#
#
# wine.mat
# 107.84306065141558
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.666667
# mad                                      0.000000         0.143885
# iqr                                      0.000000         0.645161
# default-f1                               0.333333         0.333333
# auc                                      0.475210         0.475210
# disagreement                             0.500000         0.259740
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.000000          0.000000
# mad                                          0.143885          0.000000
# iqr                                          0.000000          0.000000
# default-f1                                   0.258065          0.258065
# auc                                          0.475210          0.475210
# disagreement                                 0.000000          0.000000
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.666667     0.750000
# mad                            0.425532     0.400000
# iqr                            0.833333     0.769231
# default-f1                     0.392157     0.526316
# auc                            0.475210     0.475210
# disagreement                   0.500000     0.588235
#
#               Local Outlier Factor (LOF)  \
# sd                              0.666667
# mad                             0.143885
# iqr                             0.645161
# default-f1                      0.333333
# auc                             0.475210
# disagreement                    0.157480
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.588235               0.000000
# mad                                       0.400000               0.095238
# iqr                                       0.636364               0.105263
# default-f1                                0.322581               0.096774
# auc                                       0.475210               0.475210
# disagreement                              0.166667               0.114943
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                   6.276764e-05         2.643409
# mad                                  4.385684e-05         0.190203
# iqr                                  3.114666e-05         1.482144
# disagreement                        -3.217208e-07         1.022233
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                          20.949649          0.097284
# mad                                          6.542906          0.108296
# iqr                                         21.290711          0.091433
# disagreement                                23.932535          0.155682
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                           106.665932    55.017989
# mad                           23.030922    13.287362
# iqr                           47.369782    25.705406
# disagreement                  27.386460    18.669079
#
#               Local Outlier Factor (LOF)  \
# sd                              2.743007
# mad                             0.128663
# iqr                             1.494692
# disagreement                    0.973545
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                      106.429878               0.000518
# mad                                      24.145990               0.000338
# iqr                                      70.197373               0.000365
# disagreement                            142.067452              -0.000053
# ==============================================================================================================
#
#
#
# mnist.mat
# 6612271.553298203
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.184035
# mad                                      0.000000         0.168614
# iqr                                      0.000000         0.244618
# default-f1                               0.244344         0.257261
# auc                                      0.500000         0.500000
# disagreement                             0.233230         0.211891
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.042714          0.101611
# mad                                          0.168614          0.040984
# iqr                                          0.036223          0.081152
# default-f1                                   0.243785          0.305266
# auc                                          0.500000          0.500000
# disagreement                                 0.239636          0.340107
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.173703     0.162031
# mad                            0.169965     0.172235
# iqr                            0.161567     0.146402
# default-f1                     0.303893     0.367898
# auc                            0.500000     0.500000
# disagreement                   0.252256     0.242386
#
#               Local Outlier Factor (LOF)  \
# sd                              0.184211
# mad                             0.168614
# iqr                             0.229249
# default-f1                      0.248083
# auc                             0.500000
# disagreement                    0.205614
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.018824               0.168614
# mad                                       0.373325               0.168614
# iqr                                       0.383070               0.168614
# default-f1                                0.337878               0.000000
# auc                                       0.500000               0.500000
# disagreement                              0.002829               0.168614
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                   1.191458e-11         1.259708
# mad                                  5.219713e-12         0.179424
# iqr                                  4.197097e-12         1.234101
# disagreement                        -1.614525e-12         1.032279
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                         301.461587          0.086410
# mad                                          3.186567          0.109600
# iqr                                        301.599866          0.094494
# disagreement                               298.675732          0.014402
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                           628.113680   480.180672
# mad                          250.249669   199.137178
# iqr                          632.976854   486.327714
# disagreement                 393.122120   295.683733
#
#               Local Outlier Factor (LOF)  \
# sd                              1.240016
# mad                             0.168531
# iqr                             1.216737
# disagreement                    1.023884
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                    8.317185e+07                    0.0
# mad                                   2.122028e+02                    0.0
# iqr                                   2.681237e+03                    0.0
# disagreement                          2.845010e+08                   -0.0
# ==============================================================================================================
#
#
#
# arrhythmia.mat
# 627865.4780454746
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.292683
# mad                                      0.000000         0.254826
# iqr                                      0.000000         0.350515
# default-f1                               0.348485         0.432653
# auc                                      0.467891         0.467891
# disagreement                             0.000000         0.135135
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.195122          0.246914
# mad                                          0.254826          0.404040
# iqr                                          0.232558          0.395833
# default-f1                                   0.429150          0.429150
# auc                                          0.467891          0.467891
# disagreement                                 0.056338          0.111111
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.253165     0.207792
# mad                            0.270833     0.272527
# iqr                            0.336842     0.322581
# default-f1                     0.439834     0.453901
# auc                            0.467891     0.467891
# disagreement                   0.184211     0.136986
#
#               Local Outlier Factor (LOF)  \
# sd                              0.135135
# mad                             0.254826
# iqr                             0.350515
# default-f1                      0.436214
# auc                             0.467891
# disagreement                    0.135135
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.136986               0.000000
# mad                                       0.373444               0.253968
# iqr                                       0.478873               0.000000
# default-f1                                0.364372               0.000000
# auc                                       0.467891               0.467891
# disagreement                              0.340909               0.254826
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                   3.231405e-10         1.836089
# mad                                  2.630440e-10         0.328728
# iqr                                  2.092516e-10         1.532234
# disagreement                        -3.111202e-13         2.000852
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                         246.785909          0.106933
# mad                                         59.414008          0.074106
# iqr                                        238.871260          0.077960
# disagreement                               268.379331          0.150970
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                           299.057446   221.132637
# mad                          101.135326    80.571861
# iqr                          237.401494   182.151126
# disagreement                 340.433283   261.843586
#
#               Local Outlier Factor (LOF)  \
# sd                              1.932612
# mad                             0.329692
# iqr                             1.563965
# disagreement                    2.003275
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                    96837.976254           2.754063e-09
# mad                                     325.627447           0.000000e+00
# iqr                                    3415.460823           1.354035e-10
# disagreement                          25363.755046          -1.500600e-08
# ==============================================================================================================
#
#
#
# pendigits.mat
# 4237.649488925767
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.049315
# mad                                      0.000000         0.044406
# iqr                                      0.000000         0.051118
# default-f1                               0.063262         0.038503
# auc                                      0.935419         0.935419
# disagreement                             0.044571         0.050609
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.329749          0.378738
# mad                                          0.000000          0.352060
# iqr                                          0.333333          0.377104
# default-f1                                   0.106749          0.107438
# auc                                          0.935419          0.935419
# disagreement                                 0.129032          0.034884
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.075000     0.067485
# mad                            0.067157     0.065669
# iqr                            0.095000     0.088235
# default-f1                     0.078978     0.080851
# auc                            0.935419     0.935419
# disagreement                   0.050808     0.045667
#
#               Local Outlier Factor (LOF)  \
# sd                              0.055249
# mad                             0.044406
# iqr                             0.045662
# default-f1                      0.039384
# auc                             0.935419
# disagreement                    0.047348
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.014151               0.273292
# mad                                       0.137566               0.317460
# iqr                                       0.039301               0.311966
# default-f1                                0.107438               0.107438
# auc                                       0.935419               0.935419
# disagreement                              0.016949               0.047059
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                     311.804620         1.369033
# mad                                    118.411416         0.187195
# iqr                                    103.019777         1.255896
# disagreement                         -1076.374919         1.173092
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           2.242112          0.099869
# mad                                         13.165767          0.109562
# iqr                                          2.153678          0.101501
# disagreement                                 7.809122          0.150673
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.522285     0.375395
# mad                            0.234205     0.165562
# iqr                            0.489459     0.349111
# disagreement                   0.182117     0.104668
#
#               Local Outlier Factor (LOF)  \
# sd                              1.380080
# mad                             0.185224
# iqr                             1.254587
# disagreement                    1.174560
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                      221.072323             155.622547
# mad                                      49.160122             134.813397
# iqr                                     156.646199             131.466936
# disagreement                            198.799024             249.623277
# ==============================================================================================================
#
#
#
# musk.mat
# 149067441.80827743
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.020619
# mad                                      0.000000         0.061412
# iqr                                      0.000000         0.022727
# default-f1                               0.007491         0.043750
# auc                                      0.572822         0.572822
# disagreement                             0.061412         0.058315
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.892473          1.000000
# mad                                          0.061412          0.934066
# iqr                                          0.905473          1.000000
# default-f1                                   0.146747          0.146747
# auc                                          0.572822          0.572822
# disagreement                                 0.355932          0.962567
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.013514     0.016667
# mad                            0.061412     0.036550
# iqr                            0.000000     0.017094
# default-f1                     0.042989     0.010101
# auc                            0.572822     0.572822
# disagreement                   0.036866     0.043450
#
#               Local Outlier Factor (LOF)  \
# sd                              0.020305
# mad                             0.061412
# iqr                             0.023077
# default-f1                      0.043512
# auc                             0.572822
# disagreement                    0.059588
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.594203               0.000000
# mad                                       0.128647               0.103761
# iqr                                       0.705455               0.081855
# default-f1                                0.146747               0.093868
# auc                                       0.572822               0.572822
# disagreement                              0.916201               0.059720
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                   3.334232e-05         1.114383
# mad                                  7.494205e-12         0.087943
# iqr                                  4.419785e-12         1.100720
# disagreement                        -5.102837e-04         0.979881
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                         536.565584          0.063175
# mad                                          3.516014          0.076037
# iqr                                        536.156103          0.062836
# disagreement                               538.523343          0.073027
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                           617.035420   450.480701
# mad                          208.251270   163.526302
# iqr                          629.591654   455.538274
# disagreement                 364.882173   147.298051
#
#               Local Outlier Factor (LOF)  \
# sd                              1.116950
# mad                             0.089887
# iqr                             1.102385
# disagreement                    0.974501
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                    67978.941143               0.000687
# mad                                     664.161018               0.000246
# iqr                                   13438.225196               0.000364
# disagreement                          32467.576652              -0.000384
# ==============================================================================================================
#
#
#
# thyroid.mat
# nan
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.000000
# mad                                      0.000000         0.048124
# iqr                                      0.000000         0.276316
# default-f1                               0.000000         0.121331
# auc                                      0.843728         0.843728
# disagreement                             0.246628         0.000000
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.497890          0.563025
# mad                                          0.021277          0.459459
# iqr                                          0.425150          0.459459
# default-f1                                   0.114178          0.116105
# auc                                          0.843728          0.843728
# disagreement                                 0.056655          0.050750
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.223529     0.218391
# mad                            0.135015     0.145136
# iqr                            0.357309     0.340741
# default-f1                     0.128169     0.181263
# auc                            0.843728     0.843728
# disagreement                   0.049232     0.050516
#
#               Local Outlier Factor (LOF)  \
# sd                              0.232804
# mad                             0.048124
# iqr                             0.244318
# default-f1                      0.118029
# auc                             0.843728
# disagreement                    0.048704
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.288288               0.137500
# mad                                       0.192149               0.161943
# iqr                                       0.283019               0.169643
# default-f1                                0.116105               0.106117
# auc                                       0.843728               0.843728
# disagreement                              0.051681               0.059349
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                            NaN     1.887924e+06
# mad                                           NaN     2.420732e-01
# iqr                                           NaN     1.345631e+00
# disagreement                         -4756.197106     7.245102e+06
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                          -2.193003          0.168693
# mad                                          7.300475          0.114789
# iqr                                         -4.531328          0.115001
# disagreement                               -14.313408         -0.049913
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.150542     0.102504
# mad                            0.046078     0.032952
# iqr                            0.087642     0.061760
# disagreement                   0.010667     0.008481
#
#               Local Outlier Factor (LOF)  \
# sd                              1.659110
# mad                             0.297262
# iqr                             1.412395
# disagreement                    0.972222
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                    16606.323006              60.786809
# mad                                      22.489851              40.665942
# iqr                                      46.232761              43.769728
# disagreement                              1.384877              -9.124047
# ==============================================================================================================
#
#
#
# vowels.mat
# 954.5834676501795
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.300000
# mad                                      0.000000         0.066401
# iqr                                      0.000000         0.372093
# default-f1                               0.168675         0.163132
# auc                                      0.778336         0.778336
# disagreement                             0.066401         0.069252
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.062500          0.112676
# mad                                          0.066401          0.113208
# iqr                                          0.000000          0.129032
# default-f1                                   0.098101          0.126582
# auc                                          0.778336          0.778336
# disagreement                                 0.070028          0.083904
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.516129     0.620690
# mad                            0.084746     0.081500
# iqr                            0.571429     0.623656
# default-f1                     0.196850     0.494253
# auc                            0.778336     0.778336
# disagreement                   0.067889     0.066578
#
#               Local Outlier Factor (LOF)  \
# sd                              0.381818
# mad                             0.066401
# iqr                             0.353591
# default-f1                      0.163132
# auc                             0.778336
# disagreement                    0.070822
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.022727               0.246575
# mad                                       0.078704               0.166667
# iqr                                       0.024096               0.250000
# default-f1                                0.116904               0.123418
# auc                                       0.778336               0.778336
# disagreement                              0.071276               0.090909
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       3.207885         1.337367
# mad                                      0.419137         0.179155
# iqr                                      0.381311         1.238609
# disagreement                           -25.567397         0.975127
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                          22.260395          0.073847
# mad                                          6.138666          0.094352
# iqr                                         23.071796          0.080765
# disagreement                                14.714639         -0.029552
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             2.319503     1.543594
# mad                            1.041342     0.676642
# iqr                            2.226631     1.479408
# disagreement                   0.793143     0.405740
#
#               Local Outlier Factor (LOF)  \
# sd                              1.356429
# mad                             0.181062
# iqr                             1.242070
# disagreement                    0.975847
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                      126.136528              61.511949
# mad                                      55.568270              68.029485
# iqr                                     129.851724              63.137615
# disagreement                              5.781895              -9.261919
# ==============================================================================================================
#
#
#
# optdigits.mat
# 19869.46443862503
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.112676
# mad                                      0.000000         0.055908
# iqr                                      0.000000         0.107784
# default-f1                               0.065827         0.067003
# auc                                      0.503669         0.503669
# disagreement                             0.055619         0.059305
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.077348          0.007843
# mad                                          0.055908          0.010000
# iqr                                          0.045977          0.008000
# default-f1                                   0.122540          0.100179
# auc                                          0.503669          0.503669
# disagreement                                 0.069691          0.046243
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.043478     0.017094
# mad                            0.056001     0.054266
# iqr                            0.043478     0.017544
# default-f1                     0.045929     0.012739
# auc                            0.503669     0.503669
# disagreement                   0.052138     0.049600
#
#               Local Outlier Factor (LOF)  \
# sd                              0.097561
# mad                             0.055908
# iqr                             0.097143
# default-f1                      0.069885
# auc                             0.503669
# disagreement                    0.054445
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.000000               0.000000
# mad                                       0.008674               0.000000
# iqr                                       0.000000               0.000000
# default-f1                                0.025034               0.055456
# auc                                       0.503669               0.503669
# disagreement                              0.000000               0.057256
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                   1.896956e-06         1.207941
# mad                                  1.139349e-06         0.147875
# iqr                                  7.719795e-07         1.188656
# disagreement                        -2.788963e-06         1.025347
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                         104.632771          0.067921
# mad                                         15.983631          0.079216
# iqr                                        105.055236          0.069294
# disagreement                                86.369253          0.043127
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                            26.927032    20.240315
# mad                            9.687946     7.495566
# iqr                           26.957877    20.375743
# disagreement                  14.491377    10.409582
#
#               Local Outlier Factor (LOF)  \
# sd                              1.209276
# mad                             0.142302
# iqr                             1.185125
# disagreement                    1.009929
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                    18378.465125               0.006050
# mad                                      92.361639               0.000499
# iqr                                     198.466578               0.000486
# disagreement                          99660.375433              -0.000094
# ==============================================================================================================
#
#
#
# breastw.mat
# nan
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.000000
# mad                                      0.000000         0.518438
# iqr                                      0.000000         0.000000
# default-f1                               0.000000         0.090551
# auc                                      0.978693         0.978693
# disagreement                             0.000000         0.513939
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.000000          0.000000
# mad                                          0.912206          0.000000
# iqr                                          0.000000          0.000000
# default-f1                                   0.925781          0.929688
# auc                                          0.978693          0.978693
# disagreement                                 0.561692          0.643338
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.040984     0.024793
# mad                            0.319444     0.228782
# iqr                            0.000000     0.000000
# default-f1                     0.932540     0.891720
# auc                            0.978693     0.978693
# disagreement                   0.518438     0.518438
#
#               Local Outlier Factor (LOF)  \
# sd                              0.015686
# mad                             0.518438
# iqr                             0.082540
# default-f1                      0.250980
# auc                             0.978693
# disagreement                    0.501726
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.196226               0.000000
# mad                                       0.905303               0.000000
# iqr                                       0.253623               0.000000
# default-f1                                0.929688               0.921875
# auc                                       0.978693               0.978693
# disagreement                              0.669468               0.685796
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                            NaN     2.490202e+09
# mad                                           NaN     4.765935e-01
# iqr                                           NaN     2.857143e+08
# disagreement                                  NaN     9.947452e-01
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                          28.432986          0.219683
# mad                                         16.747104          0.315274
# iqr                                         37.765205          0.361561
# disagreement                                 5.885972         -0.121508
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             8.693649     6.275332
# mad                            6.290139     4.946379
# iqr                           11.989579     8.269521
# disagreement                   0.000000     0.000000
#
#               Local Outlier Factor (LOF)  \
# sd                              2.482509
# mad                             0.285846
# iqr                             1.718182
# disagreement                    0.980717
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                     9582.671141              22.387171
# mad                                     121.581170              17.468753
# iqr                                    5979.586155              35.880585
# disagreement                              4.159465              -1.574480
# ==============================================================================================================
#
#
#
# satellite.mat
# 5777.508700224842
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.089405
# mad                                      0.000000         0.480699
# iqr                                      0.000000         0.144061
# default-f1                               0.404733         0.408678
# auc                                      0.487310         0.487310
# disagreement                             0.008780         0.368105
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.192035          0.166294
# mad                                          0.480699          0.445530
# iqr                                          0.443024          0.408951
# default-f1                                   0.577007          0.568764
# auc                                          0.487310          0.487310
# disagreement                                 0.572622          0.263848
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.141641     0.130220
# mad                            0.505898     0.495766
# iqr                            0.207101     0.202521
# default-f1                     0.484753     0.428301
# auc                            0.487310     0.487310
# disagreement                   0.014606     0.007824
#
#               Local Outlier Factor (LOF)  \
# sd                              0.097778
# mad                             0.480699
# iqr                             0.146218
# default-f1                      0.403536
# auc                             0.487310
# disagreement                    0.390267
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.259685               0.038871
# mad                                       0.689447               0.125242
# iqr                                       0.595829               0.074894
# default-f1                                0.645987               0.340564
# auc                                       0.487310               0.487310
# disagreement                              0.000982               0.450473
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                   2.537253e-07         1.469135
# mad                                  2.806045e-07         0.280117
# iqr                                  1.749335e-07         1.395262
# disagreement                        -9.217186e-10         1.164210
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                         115.616407          0.127665
# mad                                          2.915573          0.091906
# iqr                                        114.346316          0.096633
# disagreement                               112.880053          0.113185
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                            48.189977    35.132628
# mad                           19.419862    13.808060
# iqr                           43.101765    31.558530
# disagreement                  71.119618    53.931143
#
#               Local Outlier Factor (LOF)  \
# sd                              1.476722
# mad                             0.278843
# iqr                             1.394121
# disagreement                    1.119128
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                     1014.564097               0.000490
# mad                                      65.379975               0.000202
# iqr                                     157.524244               0.000389
# disagreement                           2390.057761              -0.000200
# ==============================================================================================================
#
#
#
# lympho.mat
# 74.85559565559667
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.666667
# mad                                      0.000000         0.077922
# iqr                                      0.000000         0.714286
# default-f1                               0.166667         0.187500
# auc                                      0.977700         0.977700
# disagreement                             0.296296         0.285714
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.800000          0.909091
# mad                                          0.000000          0.909091
# iqr                                          0.857143          0.769231
# default-f1                                   0.184615          0.184615
# auc                                          0.977700          0.977700
# disagreement                                 0.800000          0.909091
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.600000     0.600000
# mad                            0.077922     0.077922
# iqr                            0.500000     0.533333
# default-f1                     0.342857     0.500000
# auc                            0.977700     0.977700
# disagreement                   0.476190     0.555556
#
#               Local Outlier Factor (LOF)  \
# sd                              0.666667
# mad                             0.077922
# iqr                             0.666667
# default-f1                      0.184615
# auc                             0.977700
# disagreement                    0.285714
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.500000               0.400000
# mad                                       0.218182               0.545455
# iqr                                       0.500000               0.545455
# default-f1                                0.184615               0.184615
# auc                                       0.977700               0.977700
# disagreement                              0.235294               0.444444
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.006399         1.218966
# mad                                      0.004032         0.112745
# iqr                                      0.003421         1.163317
# disagreement                            -0.000584         1.344739
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                         -10.533459          0.125367
# mad                                         11.054582          0.110841
# iqr                                        -12.414658          0.098495
# disagreement                                -9.720204          0.127569
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             3.669084     2.696982
# mad                            0.949257     0.779551
# iqr                            3.260276     2.429143
# disagreement                   3.162278     2.251504
#
#               Local Outlier Factor (LOF)  \
# sd                              1.218080
# mad                             0.086980
# iqr                             1.142611
# disagreement                    1.358477
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                       47.656101               7.909586
# mad                                      18.908183               7.561092
# iqr                                      42.826684               6.747274
# disagreement                             20.117246               9.317072
# ==============================================================================================================
#
#
#
# annthyroid.mat
# nan
# ...
#
#
# wbc.mat
# 171.7431074806446
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.457143
# mad                                      0.000000         0.105263
# iqr                                      0.000000         0.491228
# default-f1                               0.222222         0.251497
# auc                                      0.938242         0.938242
# disagreement                             0.160000         0.357143
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.611111          0.555556
# mad                                          0.173913          0.518519
# iqr                                          0.612245          0.518519
# default-f1                                   0.244186          0.244186
# auc                                          0.938242          0.938242
# disagreement                                 0.625000          0.370370
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.432432     0.388889
# mad                            0.124629     0.132075
# iqr                            0.549020     0.528302
# default-f1                     0.256098     0.391304
# auc                            0.938242     0.938242
# disagreement                   0.086957     0.086957
#
#               Local Outlier Factor (LOF)  \
# sd                              0.470588
# mad                             0.105263
# iqr                             0.491228
# default-f1                      0.254545
# auc                             0.938242
# disagreement                    0.344828
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.344828               0.413793
# mad                                       0.287770               0.491803
# iqr                                       0.383562               0.535714
# default-f1                                0.244186               0.232558
# auc                                       0.938242               0.938242
# disagreement                              0.387097               0.166667
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                      25.257230         1.757174
# mad                                     19.775763         0.297367
# iqr                                     19.581838         1.458776
# disagreement                            -0.005739         2.010306
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                          -5.566513          0.160262
# mad                                         33.355934          0.095124
# iqr                                        -17.757732          0.101885
# disagreement                                -2.805404          0.232212
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.791464     0.574255
# mad                            0.250513     0.188711
# iqr                            0.620420     0.446922
# disagreement                   1.205545     0.924275
#
#               Local Outlier Factor (LOF)  \
# sd                              1.743035
# mad                             0.312490
# iqr                             1.459554
# disagreement                    1.952617
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                     3473.948255               8.687930
# mad                                     112.411913               2.633241
# iqr                                     276.077308               2.924901
# disagreement                           2465.535396              18.537171
# ==============================================================================================================
#
#
#
# glass.mat
# 200.92848963822186
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.000000
# mad                                      0.000000         0.080717
# iqr                                      0.000000         0.228571
# default-f1                               0.193548         0.130435
# auc                                      0.593496         0.593496
# disagreement                             0.181818         0.300000
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.000000          0.125000
# mad                                          0.000000          0.111111
# iqr                                          0.000000          0.125000
# default-f1                                   0.084211          0.105263
# auc                                          0.593496          0.593496
# disagreement                                 0.086957          0.125000
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.117647     0.117647
# mad                            0.258065     0.222222
# iqr                            0.222222     0.227273
# default-f1                     0.206897     0.235294
# auc                            0.593496     0.593496
# disagreement                   0.095238     0.111111
#
#               Local Outlier Factor (LOF)  \
# sd                              0.133333
# mad                             0.080717
# iqr                             0.181818
# default-f1                      0.131868
# auc                             0.593496
# disagreement                    0.255319
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.000000               0.105263
# mad                                       0.202247               0.148148
# iqr                                       0.040816               0.083333
# default-f1                                0.189474               0.105263
# auc                                       0.593496               0.593496
# disagreement                              0.000000               0.095238
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                     135.297370         2.795689
# mad                                     29.490408         0.629727
# iqr                                     34.417478         1.797607
# disagreement                            -0.000025         1.713176
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           6.647519          0.190016
# mad                                         15.007944          0.178628
# iqr                                          7.558638          0.188971
# disagreement                                 2.376251          0.190864
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             3.333042     2.212136
# mad                            0.838384     0.430540
# iqr                            1.584989     0.987213
# disagreement                   2.844258     2.207048
#
#               Local Outlier Factor (LOF)  \
# sd                              3.093281
# mad                             0.675138
# iqr                             1.817078
# disagreement                    1.504148
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                     7125.607455              33.082490
# mad                                      35.469169              12.414798
# iqr                                     485.683631              29.187690
# disagreement                          19065.495843              32.469447
# ==============================================================================================================
#
#
#
# satimage-2.mat
# 4208.855669382159
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.074627
# mad                                      0.000000         0.024174
# iqr                                      0.000000         0.060150
# default-f1                               0.041651         0.020539
# auc                                      0.420907         0.420907
# disagreement                             0.090476         0.039070
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.476190          0.589286
# mad                                          0.024174          0.409496
# iqr                                          0.299020          0.350254
# default-f1                                   0.058528          0.059365
# auc                                          0.420907          0.420907
# disagreement                                 0.027778          0.027778
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.292035     0.270742
# mad                            0.031640     0.027434
# iqr                            0.203297     0.185792
# default-f1                     0.063120     0.111226
# auc                            0.420907     0.420907
# disagreement                   0.233766     0.189055
#
#               Local Outlier Factor (LOF)  \
# sd                              0.079710
# mad                             0.024174
# iqr                             0.061758
# default-f1                      0.021432
# auc                             0.420907
# disagreement                    0.037234
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.611354               0.000000
# mad                                       0.077216               0.000000
# iqr                                       0.194787               0.000000
# default-f1                                0.059365               0.020067
# auc                                       0.420907               0.420907
# disagreement                              0.404040               0.022468
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                   2.482073e-07         1.481917
# mad                                  2.813051e-07         0.272503
# iqr                                  1.756973e-07         1.389678
# disagreement                        -2.443549e-08         1.219851
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                         114.278031          0.110183
# mad                                          2.910328          0.085146
# iqr                                        113.270786          0.077847
# disagreement                               119.127767          0.300472
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                            46.146462    33.522359
# mad                           18.662439    13.187549
# iqr                           40.879043    29.914119
# disagreement                  42.544095    29.379102
#
#               Local Outlier Factor (LOF)  \
# sd                              1.485320
# mad                             0.268408
# iqr                             1.379072
# disagreement                    1.209861
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                      483.106733               0.000500
# mad                                      54.563300               0.000448
# iqr                                     111.582013               0.000523
# disagreement                           1271.701557              -0.000365
# ==============================================================================================================
#
#
#
# vertebral.mat
# 150.86201952862595
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                       0.000000         0.000000
# mad                                      0.000000         0.222222
# iqr                                      0.000000         0.040000
# default-f1                               0.125984         0.183333
# auc                                      0.625794         0.625794
# disagreement                             0.000000         0.000000
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                           0.000000          0.000000
# mad                                          0.222222          0.000000
# iqr                                          0.000000          0.000000
# default-f1                                   0.111111          0.111111
# auc                                          0.625794          0.625794
# disagreement                                 0.039216          0.000000
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                             0.000000     0.000000
# mad                            0.114286     0.079365
# iqr                            0.000000     0.000000
# default-f1                     0.088496     0.025316
# auc                            0.625794     0.625794
# disagreement                   0.000000     0.000000
#
#               Local Outlier Factor (LOF)  \
# sd                              0.000000
# mad                             0.222222
# iqr                             0.041667
# default-f1                      0.177419
# auc                             0.625794
# disagreement                    0.000000
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                        0.000000               0.000000
# mad                                       0.027397               0.000000
# iqr                                       0.000000               0.000000
# default-f1                                0.126984               0.269841
# auc                                       0.625794               0.625794
# disagreement                              0.000000               0.264706
#               Angle-based Outlier Detector (ABOD)  Feature Bagging  \
# sd                                   3.971734e-05         2.152736
# mad                                  1.173622e-05         0.235108
# iqr                                  1.605367e-05         1.300725
# disagreement                        -1.188478e-13         7.026778
#
#               Histogram-base Outlier Detection (HBOS)  Isolation Forest  \
# sd                                          19.228757          0.143777
# mad                                          0.906859          0.102229
# iqr                                         19.236822          0.117639
# disagreement                                18.948980          0.375282
#
#               K Nearest Neighbors (KNN)  Average KNN  \
# sd                            71.473083    53.479981
# mad                           16.775620    12.556720
# iqr                           34.385352    24.838450
# disagreement                 318.116255   245.874570
#
#               Local Outlier Factor (LOF)  \
# sd                              2.241742
# mad                             0.228372
# iqr                             1.292260
# disagreement                    7.624551
#
#               Minimum Covariance Determinant (MCD)  One-class SVM (OCSVM)
# sd                                      138.602298               0.000629
# mad                                      16.113625               0.000608
# iqr                                      22.683827               0.000501
# disagreement                            742.927464               0.000124
# ==============================================================================================================

# %% [markdown]
# 表现好的
